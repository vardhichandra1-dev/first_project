# %% [markdown]
# # Agent Workflow Diagram
# Run the cells below to generate and display the mermaid diagram for the workflow from `agent_graph.py`.

# %%
import sys
import os
from IPython.display import Image, display

# Ensure the backend directory is in the path
backend_dir = os.path.abspath("")
if backend_dir not in sys.path:
    sys.path.append(backend_dir)

from graphs.agent_graph import create_graph

agent = create_graph()

# %%
# Print the raw Mermaid textual representation
mermaid_text = agent.get_graph().draw_mermaid()
print(mermaid_text)
# Out:
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	router(router)
# 	authenticate(authenticate)
# 	fetch_emails(fetch_emails)
# 	classify(classify)
# 	delete(delete)
# 	notify(notify)
# 	summarize_emails(summarize_emails)
# 	search(search)
# 	chat(chat)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> router;
# 	authenticate --> fetch_emails;
# 	classify --> delete;
# 	delete --> notify;
# 	fetch_emails --> classify;
# 	notify --> summarize_emails;
# 	router -. &nbsp;email&nbsp; .-> authenticate;
# 	router -.-> chat;
# 	router -.-> search;
# 	chat --> __end__;
# 	search --> __end__;
# 	summarize_emails --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc

# %%
# Display it visually as a PNG image in the notebook
try:
    display(Image(agent.get_graph().draw_mermaid_png()))
except Exception as e:
    print("Could not render PNG. Make sure required graph libraries are installed.", e)
